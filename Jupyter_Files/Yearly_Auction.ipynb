# %%
import pandas as pd
import glob
import os

# Change year in path
directory_path = r'C:\Users\prabh\OneDrive\Desktop\IPL_Auction\All_Teams_Yearly_Data\2020_teams_data'

csv_files = glob.glob(os.path.join(directory_path, '*.csv'))
dataframes = []

for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dataframes.append(df)

combined_df = pd.concat(dataframes, ignore_index=True)
print(combined_df.head(50))
# Out:
#                       PLAYER           TYPE    PRICE PAID  Team
# 0              Piyush Chawla         Bowler   6,75,00,000     0
# 1                 Sam Curran    All-Rounder   5,50,00,000     0
# 2             Josh Hazlewood         Bowler   2,00,00,000     0
# 3             R. Sai Kishore         Bowler     20,00,000     0
# 4            Shimron Hetmyer        Batsman   7,75,00,000     1
# 5             Marcus Stoinis    All-Rounder   4,80,00,000     1
# 6                 Alex Carey  Wicket Keeper   2,40,00,000     1
# 7                  Jason Roy        Batsman   1,50,00,000     1
# 8               Chris Woakes    All-Rounder   1,50,00,000     1
# 9               Mohit Sharma         Bowler     50,00,000     1
# 10          Tushar Deshpande         Bowler     20,00,000     1
# 11               Lalit Yadav    All-Rounder     20,00,000     1
# 12             Glenn Maxwell    All-Rounder  10,75,00,000     2
# 13          Sheldon Cottrell         Bowler   8,50,00,000     2
# ...

# %%
#change year
combined_df['Year'] = 2020
print(combined_df.head(50))
# Out:
#                       PLAYER           TYPE    PRICE PAID  Team  Year
# 0              Piyush Chawla         Bowler   6,75,00,000     0  2020
# 1                 Sam Curran    All-Rounder   5,50,00,000     0  2020
# 2             Josh Hazlewood         Bowler   2,00,00,000     0  2020
# 3             R. Sai Kishore         Bowler     20,00,000     0  2020
# 4            Shimron Hetmyer        Batsman   7,75,00,000     1  2020
# 5             Marcus Stoinis    All-Rounder   4,80,00,000     1  2020
# 6                 Alex Carey  Wicket Keeper   2,40,00,000     1  2020
# 7                  Jason Roy        Batsman   1,50,00,000     1  2020
# 8               Chris Woakes    All-Rounder   1,50,00,000     1  2020
# 9               Mohit Sharma         Bowler     50,00,000     1  2020
# 10          Tushar Deshpande         Bowler     20,00,000     1  2020
# 11               Lalit Yadav    All-Rounder     20,00,000     1  2020
# ...

# %%
folder_path = r'C:\Users\prabh\OneDrive\Desktop\IPL_Auction\combined_data_per_year'  

#change year
file_path = os.path.join(folder_path, '2020_final.csv')


combined_df.to_csv(file_path, index=False)
